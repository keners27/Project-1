# %%
# Dependencies and Setup
import pandas as pd

# %%
# Load csv with school data
school_data= pd.read_csv('school-profile-2008-2021.csv')
school_data.head()
# Out:
#    Calendar Year  ACARA SML ID  Location AGE ID  School AGE ID  \
# 0           2013         50122          47943.0         7943.0
# 1           2015         43785          42021.0         2021.0
# 2           2013         43785          42021.0         2021.0
# 3           2016         43785          42021.0         2021.0
# 4           2014         43785          42021.0         2021.0
#
#                 School Name        Suburb State  Postcode School Sector  \
# 0  Tipperary Station School     Tipperary    NT       822    Government
# 1     Sydney Grammar School  Darlinghurst   NSW      2010   Independent
# 2     Sydney Grammar School  Darlinghurst   NSW      2010   Independent
# 3     Sydney Grammar School  Darlinghurst   NSW      2010   Independent
# 4     Sydney Grammar School  Darlinghurst   NSW      2010   Independent
#
#   School Type  ... Non-Teaching Staff Full Time Equivalent Non-Teaching Staff  \
# 0     Primary  ...                1.0                                     0.5
# 1    Combined  ...               90.0                                    77.7
# 2    Combined  ...               93.0                                    77.2
# 3    Combined  ...               86.0                                    75.6
# 4    Combined  ...               92.0                                    80.0
#
#   Total Enrolments Girls Enrolments Boys Enrolments  \
# 0              6.0              2.0             4.0
# 1           1860.0              0.0          1860.0
# 2           1855.0              0.0          1855.0
# 3           1855.0              0.0          1855.0
# 4           1853.0              0.0          1853.0
#
#   Full Time Equivalent Enrolments Indigenous Enrolments (%)  \
# 0                             6.0                       0.0
# 1                          1860.0                       0.0
# 2                          1855.0                       NaN
# 3                          1855.0                       NaN
# 4                          1853.0                       0.0
#
#    Language Background Other Than English - Yes (%)  \
# 0                                               0.0
# 1                                              24.0
# 2                                              28.0
# 3                                              24.0
# 4                                              27.0
#
#    Language Background Other Than English - No (%)  \
# 0                                            100.0
# 1                                             58.0
# 2                                             61.0
# 3                                             59.0
# 4                                             58.0
#
#    Language Background Other Than English - Not Stated (%)
# 0                                                0.0
# 1                                               18.0
# 2                                               11.0
# 3                                               18.0
# 4                                               15.0
#
# [5 rows x 35 columns]

# %%
# Review columns for relevance
list(school_data.columns)
# Out:
# ['Calendar Year',
#  'ACARA SML ID',
#  'Location AGE ID',
#  'School AGE ID',
#  'School Name',
#  'Suburb',
#  'State',
#  'Postcode',
#  'School Sector',
#  'School Type',
#  'Campus Type',
#  'Rolled Reporting Description',
#  'School URL',
#  'Governing Body',
#  'Governing Body URL',
#  'Year Range',
#  'Geolocation',
#  'ICSEA',
#  'ICSEA Percentile',
#  'Bottom SEA Quarter (%)',
#  'Lower Middle SEA Quarter (%)',
#  'Upper Middle SEA Quarter (%)',
#  'Top SEA Quarter (%)',
#  'Teaching Staff',
#  'Full Time Equivalent Teaching Staff',
#  'Non-Teaching Staff',
#  'Full Time Equivalent Non-Teaching Staff',
#  'Total Enrolments',
#  'Girls Enrolments',
#  'Boys Enrolments',
#  'Full Time Equivalent Enrolments',
#  'Indigenous Enrolments (%)',
#  'Language Background Other Than English - Yes (%)',
#  'Language Background Other Than English - No (%)',
#  'Language Background Other Than English - Not Stated (%)']

# %%
# Remove superflus columns
school_data = school_data[['Calendar Year',
 'School Name',
 'State',
 'Year Range',
 'ICSEA',
 'ICSEA Percentile',
 'Bottom SEA Quarter (%)',
 'Lower Middle SEA Quarter (%)',
 'Upper Middle SEA Quarter (%)',
 'Top SEA Quarter (%)',
 'Teaching Staff',
 'Full Time Equivalent Teaching Staff',
 'Full Time Equivalent Enrolments']]
school_data.head()
# Out:
#     Calendar Year                                        School Name State  \
# 6            2021                              Sydney Grammar School   NSW
# 24           2021                James Ruse Agricultural High School   NSW
# 50           2021                                Perth Modern School    WA
# 56           2021                               St Aloysius' College   NSW
# 94           2021  Queensland Academy for Science Mathematics and...   QLD
#
#    Year Range   ICSEA  ICSEA Percentile  Bottom SEA Quarter (%)  \
# 6        K-12  1281.0              99.0                     0.0
# 24       7-12  1245.0              99.0                     0.0
# 50       7-12  1237.0              99.0                     1.0
# 56       3-12  1235.0              99.0                     0.0
# 94       7-12  1224.0              99.0                     1.0
#
#     Lower Middle SEA Quarter (%)  Upper Middle SEA Quarter (%)  \
# 6                            0.0                           2.0
# 24                           5.0                          11.0
# 50                           3.0                          10.0
# 56                           1.0                           8.0
# 94                           2.0                          12.0
#
#     Top SEA Quarter (%)  Teaching Staff  Full Time Equivalent Teaching Staff  \
# 6                  97.0           269.0                                202.1
# 24                 84.0            56.0                                 60.6
# 50                 86.0           111.0                                 95.3
# 56                 91.0           119.0                                110.6
# 94                 85.0           101.0                                 98.5
#
#     Full Time Equivalent Enrolments
# 6                            1895.0
# 24                            854.5
# 50                           1440.0
# 56                           1277.0
# 94                           1237.6

# %%
# Remove rows with null data
school_data.dropna(how='any',inplace=True)
# Out:
# C:\Users\Carol's PC\AppData\Local\Temp\ipykernel_6216\2641378391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   school_data.dropna(how='any',inplace=True)

# %%
# Remove school profiles from the previous years
school_data = school_data.loc[school_data["Calendar Year"] == 2021]
school_data
# Out:
#         Calendar Year                                        School Name  \
# 6                2021                              Sydney Grammar School
# 24               2021                James Ruse Agricultural High School
# 50               2021                                Perth Modern School
# 56               2021                               St Aloysius' College
# 94               2021  Queensland Academy for Science Mathematics and...
# ...               ...                                                ...
# 123858           2021                                   Amoonguna School
# 123874           2021                   Carinity Education - Rockhampton
# 123877           2021                            Mapuru Yirralka College
# 123884           2021                                        Mian School
# 123887           2021             Deception Bay Flexible Learning Centre
#
#        State Year Range   ICSEA  ICSEA Percentile  Bottom SEA Quarter (%)  \
# 6        NSW       K-12  1281.0              99.0                     0.0
# 24       NSW       7-12  1245.0              99.0                     0.0
# 50        WA       7-12  1237.0              99.0                     1.0
# 56       NSW       3-12  1235.0              99.0                     0.0
# 94       QLD       7-12  1224.0              99.0                     1.0
# ...      ...        ...     ...               ...                     ...
# 123858    NT        P-6   355.0               0.0                   100.0
# 123874   QLD       7-12   228.0               0.0                   100.0
# 123877    NT       T-10   175.0               0.0                   100.0
# 123884   NSW          U   100.0               0.0                   100.0
# 123887   QLD       5-12   100.0               0.0                   100.0
#
#         Lower Middle SEA Quarter (%)  Upper Middle SEA Quarter (%)  \
# 6                                0.0                           2.0
# 24                               5.0                          11.0
# 50                               3.0                          10.0
# 56                               1.0                           8.0
# 94                               2.0                          12.0
# ...                              ...                           ...
# 123858                           0.0                           0.0
# 123874                           0.0                           0.0
# 123877                           0.0                           0.0
# 123884                           0.0                           0.0
# 123887                           0.0                           0.0
#
#         Top SEA Quarter (%)  Teaching Staff  \
# 6                      97.0           269.0
# 24                     84.0            56.0
# 50                     86.0           111.0
# 56                     91.0           119.0
# 94                     85.0           101.0
# ...                     ...             ...
# 123858                  0.0             1.0
# 123874                  0.0            25.0
# 123877                  0.0             6.0
# 123884                  0.0             5.0
# 123887                  0.0            14.0
#
#         Full Time Equivalent Teaching Staff  Full Time Equivalent Enrolments
# 6                                     202.1                           1895.0
# 24                                     60.6                            854.5
# 50                                     95.3                           1440.0
# 56                                    110.6                           1277.0
# 94                                     98.5                           1237.6
# ...                                     ...                              ...
# 123858                                  1.0                             20.0
# 123874                                 20.4                            246.0
# 123877                                  6.0                             62.0
# 123884                                  7.9                             17.0
# 123887                                 11.4                            128.8
#
# [9505 rows x 13 columns]
